# %%
with open('cleaned_tweets.txt_tagged') as fp:
  tagged_tweets = fp.readlines()
tagged = []
for i in range(0, len(tagged_tweets)):
    if i % 2 != 0:
        tagged.append(tagged_tweets[i])
    else:
        pass
  
tagged[:5]
# Out:
# ['0\t#notebandi/OTHER se/EN kuch/HI fyda/HI nahi/HI hua/EN lekin/HI yeh/HI baat/HI public/EN tak/HI nahi/HI pahuncha/HI sake/EN root/EN level/EN se/EN kaam/HI nahi/HI hua/EN \n',
#  '1\tkabhi/HI aap/EN logo/EN na/EN lokpal/HI par/EN baat/HI ki/EN kyo/HI aakhir/HI modi/HI ji/EN na/EN kya/EN de/EN rakha/HI hai/EN media/EN ko/EN naxali/HI aatankwad/HI #notebandi/OTHER sa/EN kya/EN mila/HI \n',
#  '2\tinle/EN bas/EN ki/EN baat/HI nahi/HI hai/EN vishwas/HI dila/HI pana/HI ye/EN kewal/HI #notebandi/OTHER jaisa/HI disruption/EN hi/EN kar/HI sakte/HI hain/EN jiska/HI result/EN zero/EN hai/EN \n',
#  '3\tb/EN chadha/HI elections/EN se/EN pehle/HI tum/HI logon/EN ne/EN #notebandi/OTHER ka/EN mudda/HI uthaya/HI janta/HI ne/EN tum/HI logon/EN ki/EN okat/EN tumhe/HI dikha/HI di/EN ab/EN #evm/OTHER ka/EN bhana/HI jo/EN mcd/EN k/EN baad/HI khtam/HI \n',
#  '4\tye/EN chote/HI phaisale/HI lene/HI se/EN kuch/HI nahi/HI hoga/HI lena/EN hai/EN to/EN strong/EN action/EN lo/EN nahi/HI to/EN chod/HI do/EN \n']

# %%
import regex as re

# %%
import pandas as pd

tweetdf = pd.read_csv('cleaned_tweets.txt_tagged',sep='\t',skiprows=lambda x: x%2 == 0)
tweetdf.columns = ['Index','Tweet']

tweetdf
# Out:
#       Index                                              Tweet
# 0         1  kabhi/HI aap/EN logo/EN na/EN lokpal/HI par/EN...
# 1         2  inle/EN bas/EN ki/EN baat/HI nahi/HI hai/EN vi...
# 2         3  b/EN chadha/HI elections/EN se/EN pehle/HI tum...
# 3         4  ye/EN chote/HI phaisale/HI lene/HI se/EN kuch/...
# 4         5  naqli/HI note/EN ke/EN liye/HI #notebandi/OTHE...
# ...     ...                                                ...
# 9448   9449  chandu/HI bhai/HI aap/EN yeh/EN troll/EN gang/...
# 9449   9450  yogi/EN up/EN ke/EN sadkein/HI gaddha/HI mukt/...
# 9450   9451  aur/HI kher/HI ji/EN aisa/EN kyon/HI hai/EN ki...
# 9451   9452  sir/EN yeh/HI topi/HI pehan/HI kar/HI train/EN...
# 9452   9453  she/EN kya/EN aap/EN ke/EN toothpaste/EN mein/...
#
# [9453 rows x 2 columns]

# %%
tweetdf['Hindi'] = " "
tweetdf['English'] = " "
tweetdf['Other'] = " "

# %%
for i in range(len(tweetdf)):
  english = []
  hindi = []
  other = []
  hindi_x = ''    
  english_x = ''
  other_x = ''
  tweet = str(tweetdf['Tweet'][i]).split()
  for j in range(len(tweet)):
    if j%2==1:
      continue
    if (tweet[j][-1]=='I'):
      tweet[j] = re.sub('/HI','',tweet[j])
      hindi.append(tweet[j])
    elif (tweet[j][-1]=='N'):
      tweet[j] = re.sub('/EN','',tweet[j])
      english.append(tweet[j])
    else:
      tweet[j] = re.sub('/OTHER','',tweet[j])
      if tweet[j][0] == "#":
        tweet[j] = tweet[j][1:]
      other.append(tweet[j])
  hindi_x = ' '.join(hindi)
  tweetdf['Hindi'][i]=hindi_x
  english_x = ' '.join(english)
  tweetdf['English'][i]=english_x
  other_x = ' '.join(other)
  tweetdf['Other'][i]=other_x
# Out:
# /tmp/ipykernel_2471/3203656266.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweetdf['Hindi'][i]=hindi_x
# /tmp/ipykernel_2471/3203656266.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweetdf['English'][i]=english_x
# /tmp/ipykernel_2471/3203656266.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweetdf['Other'][i]=other_x

# %%
tweetdf.drop(['Index'],axis=1)
# Out:
#                                                   Tweet  \
# 0     kabhi/HI aap/EN logo/EN na/EN lokpal/HI par/EN...
# 1     inle/EN bas/EN ki/EN baat/HI nahi/HI hai/EN vi...
# 2     b/EN chadha/HI elections/EN se/EN pehle/HI tum...
# 3     ye/EN chote/HI phaisale/HI lene/HI se/EN kuch/...
# 4     naqli/HI note/EN ke/EN liye/HI #notebandi/OTHE...
# ...                                                 ...
# 9448  chandu/HI bhai/HI aap/EN yeh/EN troll/EN gang/...
# 9449  yogi/EN up/EN ke/EN sadkein/HI gaddha/HI mukt/...
# 9450  aur/HI kher/HI ji/EN aisa/EN kyon/HI hai/EN ki...
# 9451  sir/EN yeh/HI topi/HI pehan/HI kar/HI train/EN...
# 9452  she/EN kya/EN aap/EN ke/EN toothpaste/EN mein/...
#
#                                           Hindi  \
# 0     kabhi lokpal baat kyo modi aatankwad mila
# 1     nahi vishwas pana kewal jaisa sakte jiska
# 2        pehle mudda janta tum tumhe bhana baad
# 3                       phaisale nahi nahi chod
# 4                          naqli sakti liye kyo
# ...                                         ...
# 9448                          chandu kabse rahe
# 9449            gaddha hogi yeh mukt prerna atj
# 9450          aur kyon unhi khade dikhai bharat
# 9451                   topi kar zamana bhi bhej
# 9452                                       japz
#
#                                            English          Other
# 0                             logo na de hai ko sa
# 1                                  inle ki hi zero
# 2                      b elections logon ki di mcd  notebandi evm
# 3                             ye se lena to action
# 4                                       ke to vote      notebandi
# ...                                            ...            ...
# 9448                          aap troll pic com lw
# 9449  yogi ke as to hai editor ji hai okay twitter
# 9450              ji ki her ke hai intolerance hai
# 9451                               sir mein na hai
# 9452           she aap toothpaste cens hai pic com
#
# [9453 rows x 4 columns]

# %%
import nltk
#generate english POS tags
for i in range(len(tweetdf)):
    text = tweetdf['English'][i]
    tokens = nltk.word_tokenize(text)
    tag = nltk.pos_tag(tokens)
    tweetdf['English'][i] = tag
    text_other = tweetdf['Other'][i]
    tokens_other = nltk.word_tokenize(text_other)
    tag_other = nltk.pos_tag(tokens_other)
    tweetdf['Other'][i] = tag_other
# Out:
# /tmp/ipykernel_2471/2325755707.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweetdf['English'][i] = tag
# /tmp/ipykernel_2471/2325755707.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweetdf['Other'][i] = tag_other

# %%
tweetdf
# Out:
#       Index                                              Tweet  \
# 0         1  kabhi/HI aap/EN logo/EN na/EN lokpal/HI par/EN...
# 1         2  inle/EN bas/EN ki/EN baat/HI nahi/HI hai/EN vi...
# 2         3  b/EN chadha/HI elections/EN se/EN pehle/HI tum...
# 3         4  ye/EN chote/HI phaisale/HI lene/HI se/EN kuch/...
# 4         5  naqli/HI note/EN ke/EN liye/HI #notebandi/OTHE...
# ...     ...                                                ...
# 9448   9449  chandu/HI bhai/HI aap/EN yeh/EN troll/EN gang/...
# 9449   9450  yogi/EN up/EN ke/EN sadkein/HI gaddha/HI mukt/...
# 9450   9451  aur/HI kher/HI ji/EN aisa/EN kyon/HI hai/EN ki...
# 9451   9452  sir/EN yeh/HI topi/HI pehan/HI kar/HI train/EN...
# 9452   9453  she/EN kya/EN aap/EN ke/EN toothpaste/EN mein/...
#
#                                           Hindi  \
# 0     kabhi lokpal baat kyo modi aatankwad mila
# 1     nahi vishwas pana kewal jaisa sakte jiska
# 2        pehle mudda janta tum tumhe bhana baad
# 3                       phaisale nahi nahi chod
# 4                          naqli sakti liye kyo
# ...                                         ...
# 9448                          chandu kabse rahe
# 9449            gaddha hogi yeh mukt prerna atj
# 9450          aur kyon unhi khade dikhai bharat
# 9451                   topi kar zamana bhi bhej
# 9452                                       japz
#
#                                                 English  \
# 0     [(logo, NN), (na, FW), (de, FW), (hai, FW), (k...
# 1          [(inle, NN), (ki, NN), (hi, NN), (zero, NN)]
# 2     [(b, NN), (elections, NNS), (logon, VBP), (ki,...
# 3     [(ye, NN), (se, NN), (lena, NN), (to, TO), (ac...
# 4                      [(ke, NN), (to, TO), (vote, VB)]
# ...                                                 ...
# 9448  [(aap, NN), (troll, NN), (pic, NN), (com, NN),...
# 9449  [(yogi, RB), (ke, NN), (as, IN), (to, TO), (ha...
# 9450  [(ji, NN), (ki, VBD), (her, PRP$), (ke, NN), (...
# 9451       [(sir, NN), (mein, NN), (na, TO), (hai, NN)]
# 9452  [(she, PRP), (aap, VBD), (toothpaste, NN), (ce...
#
#                                Other
# 0                                 []
# 1                                 []
# 2     [(notebandi, NNS), (evm, VBP)]
# 3                                 []
# 4                  [(notebandi, NN)]
# ...                              ...
# 9448                              []
# 9449                              []
# 9450                              []
# 9451                              []
# 9452                              []
#
# [9453 rows x 5 columns]

# %%
import sys
from decimal import *
import codecs

tag_set = set()
word_set = set()

def parse_traindata():
    fin = "model/hmmmodel.txt"
    output_file = "outputs/hmmmoutput.txt"
    transition_prob = {}
    emission_prob = {}
    tag_list = []
    tag_count ={}
    global tag_set
    try:
        input_file = codecs.open(fin,mode ='r', encoding="utf-8")
        lines = input_file.readlines()
        flag = False
        for line in lines:
            line = line.strip('\n')
            if line != "Emission Model":
                i = line[::-1]
                key_insert = line[:-i.find(":")-1]
                value_insert = line.split(":")[-1]

                # for transition probabilities #
                if flag == False:
                    transition_prob[key_insert] = value_insert
                    if (key_insert.split("~tag~")[0] not in tag_list) and (key_insert.split("~tag~")[0] != "start"):
                        tag_list.append(key_insert.split("~tag~")[0])

                else:
                    # for emission probabilities #
                    emission_prob[key_insert] = value_insert
                    val = key_insert.split("/")[-1]
                    j = key_insert[::-1]
                    word = key_insert[:-j.find("/")-1].lower()
                    word_set.add(word)
                    if val in tag_count:
                        tag_count[val] +=1
                    else:
                        tag_count[val] = 1
                    tag_set.add(val)

            else:
                flag = True
                continue

        input_file.close()
        return tag_list, transition_prob, emission_prob, tag_count, word_set

    except IOError:
        fo = codecs.open(output_file, mode='w',encoding="utf-8")
        fo.write("File not found: {}".format(fin))
        fo.close()
        sys.exit()


def viterbi_algorithm(sentence, tag_list, transition_prob, emission_prob,tag_count, word_set):
    global tag_set
    # Get words from each sentence #
    sentence = sentence.strip("\n")
    word_list = sentence.split(" ")
    current_prob = {}
    for tag in tag_list:
        # transition probability #
        tp = Decimal(0)
        # Emission probability #
        em = Decimal(0)
        # Storing the probability of every tag to be starting tag #
        if "start~tag~"+tag in transition_prob:
            tp = Decimal(transition_prob["start~tag~"+tag])
        # Check for word in training data. If present, check the probability of the first word to be of given tag#
        if word_list[0].lower() in word_set:
            if (word_list[0].lower()+"/"+tag) in emission_prob:
                em = Decimal(emission_prob[word_list[0].lower()+"/"+tag])
                # Storing probability of current combination of tp and em #
                current_prob[tag] = tp * em
         # Check for word in training data. If absent then probability is just tp# 
        else:
            em = Decimal(1) /(tag_count[tag] +len(word_set))
            current_prob[tag] = tp

    if len(word_list) == 1:
        # Return max path if only one word in sentence #
        max_path = max(current_prob, key=current_prob.get)
        return max_path
    else:
        # Tracking from second word to last word #
        for i in range(1, len(word_list)):
            previous_prob = current_prob
            current_prob = {}
            locals()['dict{}'.format(i)] = {}
            previous_tag = ""
            for tag in tag_list:
                if word_list[i].lower() in word_set:
                    if word_list[i].lower()+"/"+tag in emission_prob:
                        em = Decimal(emission_prob[word_list[i].lower()+"/"+tag])
                        # Find the maximum probability using previous node's(tp*em)[i.e probability of reaching to the previous node] * tp * em (Bigram Model) #
                        max_prob, previous_state = max((Decimal(previous_prob[previous_tag]) * Decimal(transition_prob[previous_tag + "~tag~" + tag]) * em, previous_tag) for previous_tag in previous_prob)
                        current_prob[tag] = max_prob
                        locals()['dict{}'.format(i)][previous_state + "~" + tag] = max_prob
                        previous_tag = previous_state
                else:
                    em = Decimal(1) /(tag_count[tag] +len(word_set))
                    max_prob, previous_state = max((Decimal(previous_prob[previous_tag]) * Decimal(transition_prob[previous_tag+"~tag~"+tag]) * em, previous_tag) for previous_tag in previous_prob)
                    current_prob[tag] = max_prob
                    locals()['dict{}'.format(i)][previous_state + "~" + tag] = max_prob
                    previous_tag = previous_state

            # if last word of sentence, then return path dicts of all words #
            if i == len(word_list)-1:
                max_path = ""
                last_tag = max(current_prob, key=current_prob.get)
                max_path = max_path + last_tag + " " + previous_tag
                for j in range(len(word_list)-1,0,-1):
                    for key in locals()['dict{}'.format(j)]:
                        data = key.split("~")
                        if data[-1] == previous_tag:
                            max_path = max_path + " " +data[0]
                            previous_tag = data[0]
                            break
                result = max_path.split()
                result.reverse()
                return " ".join(result)



tag_list, transition_model, emission_model, tag_count, word_set = parse_traindata()


# predicted = codecs.open("outputs/hmmoutput.txt", mode ='r', encoding="utf-8")
# expected = codecs.open("test_data/test_tagged.txt", mode ='r', encoding="utf-8")

# c = 0
# total = 0
# for line in predicted.readlines():
#     u = line.split(" ")
#     total += len(u)
#     a = expected.readline().split(" ")
#     for i in range(len(u)):
#         if(a[i]!=u[i]):
#             c+=1

# print("Wrong Predictions = ",c)
# print("Total Predictions = ",total)
# print("Accuracy is = ",100 - (c/total * 100),"%")

# %%
from indic_transliteration import sanscript
from indic_transliteration.sanscript import transliterate

def POS_Tags_Hindi(input_sent):
    ret_list = []
    input_sent_copy = input_sent
    input_sent = transliterate(input_sent, sanscript.ITRANS, sanscript.DEVANAGARI)
    path = viterbi_algorithm(input_sent, tag_list, transition_model, emission_model,tag_count, word_set)
    word = input_sent_copy.split(" ")
    tag = path.split(" ")
    for j in range(0,len(word)):
        ret_list.append(tuple((word[j],tag[j])))
        # ret_string += word[j] + "/" + tag[j] + " "
    return ret_list

# %%
#generate hindi POS tags
for i in range(len(tweetdf)):
    text = tweetdf['Hindi'][i]
    tweetdf['Hindi'][i] = POS_Tags_Hindi(tweetdf['Hindi'][i])
# Out:
# /tmp/ipykernel_2471/3702503715.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweetdf['Hindi'][i] = POS_Tags_Hindi(tweetdf['Hindi'][i])

# %%
type(tweetdf["English"][0][0])
# Out:
# tuple

# %%
tweetdf
# Out:
#       Index                                              Tweet  \
# 0         1  kabhi/HI aap/EN logo/EN na/EN lokpal/HI par/EN...
# 1         2  inle/EN bas/EN ki/EN baat/HI nahi/HI hai/EN vi...
# 2         3  b/EN chadha/HI elections/EN se/EN pehle/HI tum...
# 3         4  ye/EN chote/HI phaisale/HI lene/HI se/EN kuch/...
# 4         5  naqli/HI note/EN ke/EN liye/HI #notebandi/OTHE...
# ...     ...                                                ...
# 9448   9449  chandu/HI bhai/HI aap/EN yeh/EN troll/EN gang/...
# 9449   9450  yogi/EN up/EN ke/EN sadkein/HI gaddha/HI mukt/...
# 9450   9451  aur/HI kher/HI ji/EN aisa/EN kyon/HI hai/EN ki...
# 9451   9452  sir/EN yeh/HI topi/HI pehan/HI kar/HI train/EN...
# 9452   9453  she/EN kya/EN aap/EN ke/EN toothpaste/EN mein/...
#
#                                                   Hindi  \
# 0     [(kabhi, QFC), (lokpal, QF), (baat, NN), (kyo,...
# 1     [(nahi, UNK), (vishwas, VM), (pana, VAUX), (ke...
# 2     [(pehle, UNK), (mudda, VM), (janta, VAUX), (tu...
# 3     [(phaisale, NN), (nahi, VM), (nahi, VAUX), (ch...
# 4     [(naqli, QO), (sakti, NN), (liye, PSP), (kyo, ...
# ...                                                 ...
# 9448          [(chandu, INTF), (kabse, JJ), (rahe, VM)]
# 9449  [(gaddha, UNK), (hogi, VM), (yeh, VAUX), (mukt...
# 9450  [(aur, UNK), (kyon, VM), (unhi, VAUX), (khade,...
# 9451  [(topi, UNK), (kar, VM), (zamana, VAUX), (bhi,...
# 9452                                      [(japz, INJ)]
#
#                                                 English  \
# 0     [(logo, NN), (na, FW), (de, FW), (hai, FW), (k...
# 1          [(inle, NN), (ki, NN), (hi, NN), (zero, NN)]
# 2     [(b, NN), (elections, NNS), (logon, VBP), (ki,...
# 3     [(ye, NN), (se, NN), (lena, NN), (to, TO), (ac...
# 4                      [(ke, NN), (to, TO), (vote, VB)]
# ...                                                 ...
# 9448  [(aap, NN), (troll, NN), (pic, NN), (com, NN),...
# 9449  [(yogi, RB), (ke, NN), (as, IN), (to, TO), (ha...
# 9450  [(ji, NN), (ki, VBD), (her, PRP$), (ke, NN), (...
# 9451       [(sir, NN), (mein, NN), (na, TO), (hai, NN)]
# 9452  [(she, PRP), (aap, VBD), (toothpaste, NN), (ce...
#
#                                Other
# 0                                 []
# 1                                 []
# 2     [(notebandi, NNS), (evm, VBP)]
# 3                                 []
# 4                  [(notebandi, NN)]
# ...                              ...
# 9448                              []
# 9449                              []
# 9450                              []
# 9451                              []
# 9452                              []
#
# [9453 rows x 5 columns]

# %%
tweetdf.to_csv('hi-en_postags.csv')

# %%
tweetdf.drop(['Index'], axis=1)
# Out:
#                                                   Tweet  \
# 0     kabhi/HI aap/EN logo/EN na/EN lokpal/HI par/EN...
# 1     inle/EN bas/EN ki/EN baat/HI nahi/HI hai/EN vi...
# 2     b/EN chadha/HI elections/EN se/EN pehle/HI tum...
# 3     ye/EN chote/HI phaisale/HI lene/HI se/EN kuch/...
# 4     naqli/HI note/EN ke/EN liye/HI #notebandi/OTHE...
# ...                                                 ...
# 9448  chandu/HI bhai/HI aap/EN yeh/EN troll/EN gang/...
# 9449  yogi/EN up/EN ke/EN sadkein/HI gaddha/HI mukt/...
# 9450  aur/HI kher/HI ji/EN aisa/EN kyon/HI hai/EN ki...
# 9451  sir/EN yeh/HI topi/HI pehan/HI kar/HI train/EN...
# 9452  she/EN kya/EN aap/EN ke/EN toothpaste/EN mein/...
#
#                                           Hindi  \
# 0     kabhi lokpal baat kyo modi aatankwad mila
# 1     nahi vishwas pana kewal jaisa sakte jiska
# 2        pehle mudda janta tum tumhe bhana baad
# 3                       phaisale nahi nahi chod
# 4                          naqli sakti liye kyo
# ...                                         ...
# 9448                          chandu kabse rahe
# 9449            gaddha hogi yeh mukt prerna atj
# 9450          aur kyon unhi khade dikhai bharat
# 9451                   topi kar zamana bhi bhej
# 9452                                       japz
#
#                                                 English            Other
# 0     [(logo, NN), (na, FW), (de, FW), (hai, FW), (k...
# 1          [(inle, NN), (ki, NN), (hi, NN), (zero, NN)]
# 2     [(b, NN), (elections, NNS), (logon, VBP), (ki,...  #notebandi #evm
# 3     [(ye, NN), (se, NN), (lena, NN), (to, TO), (ac...
# 4                      [(ke, NN), (to, TO), (vote, VB)]       #notebandi
# ...                                                 ...              ...
# 9448  [(aap, NN), (troll, NN), (pic, NN), (com, NN),...
# 9449  [(yogi, RB), (ke, NN), (as, IN), (to, TO), (ha...
# 9450  [(ji, NN), (ki, VBD), (her, PRP$), (ke, NN), (...
# 9451       [(sir, NN), (mein, NN), (na, TO), (hai, NN)]
# 9452  [(she, PRP), (aap, VBD), (toothpaste, NN), (ce...
#
# [9453 rows x 4 columns]
